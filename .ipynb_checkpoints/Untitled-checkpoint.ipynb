# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.pipeline import make_pipeline,Pipeline
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score,roc_curve,precision_recall_curve, average_precision_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
columns = [
'duration',
'protocol_type',
'service',
'flag',
'src_bytes',
'dst_bytes',
'land',
'wrong_fragment',
'urgent',
'hot',
'num_failed_logins',
'logged_in',
'num_compromised',
'root_shell',
'su_attempted',
'num_root',
'num_file_creations',
'num_shells',
'num_access_files',
'num_outbound_cmds',
'is_host_login',
'is_guest_login',
'count',
'srv_count',
'serror_rate',
'srv_serror_rate',
'rerror_rate',
'srv_rerror_rate',
'same_srv_rate',
'diff_srv_rate',
'srv_diff_host_rate',
'dst_host_count',
'dst_host_srv_count',
'dst_host_same_srv_rate',
'dst_host_diff_srv_rate',
'dst_host_same_src_port_rate',
'dst_host_srv_diff_host_rate',
'dst_host_serror_rate',
'dst_host_srv_serror_rate',
'dst_host_rerror_rate',
'dst_host_srv_rerror_rate',
'attack',
'difficulty'
]

# %%
df1 = pd.read_csv("Data/train.txt",names=columns)
df2 = pd.read_csv("Data/test.txt",names=columns)

# %%
df1.head(10)
# Out:
#    duration protocol_type     service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp    ftp_data   SF        491          0     0
# 1         0           udp       other   SF        146          0     0
# 2         0           tcp     private   S0          0          0     0
# 3         0           tcp        http   SF        232       8153     0
# 4         0           tcp        http   SF        199        420     0
# 5         0           tcp     private  REJ          0          0     0
# 6         0           tcp     private   S0          0          0     0
# 7         0           tcp     private   S0          0          0     0
# 8         0           tcp  remote_job   S0          0          0     0
# 9         0           tcp     private   S0          0          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
# 5               0       0    0  ...                    0.07
# 6               0       0    0  ...                    0.04
# 7               0       0    0  ...                    0.06
# 8               0       0    0  ...                    0.09
# 9               0       0    0  ...                    0.05
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
# 5                    0.07                         0.00
# 6                    0.05                         0.00
# 7                    0.07                         0.00
# 8                    0.05                         0.00
# 9                    0.06                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
# 5                         0.00                  0.00
# 6                         0.00                  1.00
# 7                         0.00                  1.00
# 8                         0.00                  1.00
# 9                         0.00                  1.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
# 5                      0.00                  1.00                      1.00
# 6                      1.00                  0.00                      0.00
# 7                      1.00                  0.00                      0.00
# 8                      1.00                  0.00                      0.00
# 9                      1.00                  0.00                      0.00
#
#     attack  difficulty
# 0   normal          20
# 1   normal          15
# 2  neptune          19
# 3   normal          21
# 4   normal          21
# 5  neptune          21
# 6  neptune          21
# 7  neptune          21
# 8  neptune          21
# 9  neptune          21
#
# [10 rows x 43 columns]

# %%
df1["attack"] = df1["attack"].apply(lambda x:0 if x=="normal" else 1)
df2["attack"] = df2["attack"].apply(lambda x:0 if x=="normal" else 1)

# %%
df1["wrong_fragment"].unique()
# Out:
# array([0, 3, 1])

# %%
df1["dst_host_srv_rerror_rate"].value_counts()
# Out:
# dst_host_srv_rerror_rate
# 0.00    106616
# 1.00     13231
# 0.01      1390
# 0.02       580
# 0.03       352
#          ...
# 0.30         6
# 0.28         5
# 0.21         5
# 0.26         3
# 0.43         3
# Name: count, Length: 101, dtype: int64

# %%
pd.crosstab(df1["num_access_files"], df1["attack"])
# Out:
# attack                0      1
# num_access_files
# 0                 66982  58620
# 1                   304      9
# 2                    28      1
# 3                     8      0
# 4                     5      0
# 5                     6      0
# 6                     4      0
# 7                     2      0
# 8                     3      0
# 9                     1      0

# %%
df1["attack"].unique()
# Out:
# array([0, 1])

# %%
df1.drop("difficulty",axis=1,inplace=True)
df2.drop("difficulty",axis=1,inplace=True)

# %%
df1["attack"].value_counts()
# Out:
# attack
# 0    67343
# 1    58630
# Name: count, dtype: int64

# %%
corr = df1.corr(numeric_only = True)

# %%
corr_attack = corr["attack"].sort_values(ascending=False)
plt.figure(figsize=(10, 12))
colors = ["red" if x < 0 else "green" for x in corr_attack]
plt.axvline(0, color="black", linewidth=1)
plt.barh(corr_attack.index, corr_attack.values,color=colors)
plt.title("Correlation of Num Features with Attack")
plt.xlabel("Correlation")
plt.ylabel("Features")
plt.grid(axis="x", linestyle="--", alpha=0.6)

# %%
x_train = df1.drop("attack",axis=1)
y_train = df1["attack"]

# %%
x_test = df2.drop("attack",axis=1)
y_test = df2["attack"]

# %%
(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# ((125973, 41), (125973,), (22544, 41), (22544,))

# %%
num_attribute = []
cat_attribute = []
for col in x_train.columns :
    if df1[col].dtype == "object":
        cat_attribute.append(col)
    else:
        num_attribute.append(col)
num_pipeline = Pipeline([
    ('Scaler',StandardScaler())
])
cat_pipeline = Pipeline([
    ('Onehot',OneHotEncoder(handle_unknown='ignore'))
])
full_pipeline = ColumnTransformer([
    ("num",num_pipeline,num_attribute),
    ("cat",cat_pipeline,cat_attribute)
])

# %%
lr = make_pipeline(full_pipeline,LogisticRegression(n_jobs=-1))
lr.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'src_bytes',
#                                                    'dst_bytes', 'land',
#                                                    'wrong_fragment', 'urgent',
#                                                    'hot', 'num_failed_logins',
#                                                    'logged_in',
#                                                    'num_compromised',
#                                                    'root_shell', 'su_attempted',
#                                                    'num_root',
#                                                    'num_file_creations',
#                                                    'num_shells',
#                                                    'num_access_files',
#                                                    'num_outbou...
#                                                    'is_guest_login', 'count',
#                                                    'srv_count', 'serror_rate',
#                                                    'srv_serror_rate',
#                                                    'rerror_rate',
#                                                    'srv_rerror_rate',
#                                                    'same_srv_rate',
#                                                    'diff_srv_rate',
#                                                    'srv_diff_host_rate',
#                                                    'dst_host_count',
#                                                    'dst_host_srv_count', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('Onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['protocol_type', 'service',
#                                                    'flag'])])),
#                 ('logisticregression', LogisticRegression(n_jobs=-1))])

# %%
pred = lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# 0.7532381121362669

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[8991,  720],
#        [4843, 7990]])

# %%
dt = make_pipeline(full_pipeline,DecisionTreeClassifier(random_state=42))
dt.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'src_bytes',
#                                                    'dst_bytes', 'land',
#                                                    'wrong_fragment', 'urgent',
#                                                    'hot', 'num_failed_logins',
#                                                    'logged_in',
#                                                    'num_compromised',
#                                                    'root_shell', 'su_attempted',
#                                                    'num_root',
#                                                    'num_file_creations',
#                                                    'num_shells',
#                                                    'num_access_files',
#                                                    'num_outbou...
#                                                    'srv_count', 'serror_rate',
#                                                    'srv_serror_rate',
#                                                    'rerror_rate',
#                                                    'srv_rerror_rate',
#                                                    'same_srv_rate',
#                                                    'diff_srv_rate',
#                                                    'srv_diff_host_rate',
#                                                    'dst_host_count',
#                                                    'dst_host_srv_count', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('Onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['protocol_type', 'service',
#                                                    'flag'])])),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(random_state=42))])

# %%
pred = dt.predict(x_test)

# %%
dt.score(x_test,y_test)
# Out:
# 0.7854418026969482

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[9408,  303],
#        [4534, 8299]])

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.97      0.80      9711
#            1       0.96      0.65      0.77     12833
#
#     accuracy                           0.79     22544
#    macro avg       0.82      0.81      0.78     22544
# weighted avg       0.84      0.79      0.78     22544

# %%
rc = make_pipeline(full_pipeline,RandomForestClassifier(random_state=42,n_jobs=-1))
rc.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'src_bytes',
#                                                    'dst_bytes', 'land',
#                                                    'wrong_fragment', 'urgent',
#                                                    'hot', 'num_failed_logins',
#                                                    'logged_in',
#                                                    'num_compromised',
#                                                    'root_shell', 'su_attempted',
#                                                    'num_root',
#                                                    'num_file_creations',
#                                                    'num_shells',
#                                                    'num_access_files',
#                                                    'num_outbou...
#                                                    'srv_count', 'serror_rate',
#                                                    'srv_serror_rate',
#                                                    'rerror_rate',
#                                                    'srv_rerror_rate',
#                                                    'same_srv_rate',
#                                                    'diff_srv_rate',
#                                                    'srv_diff_host_rate',
#                                                    'dst_host_count',
#                                                    'dst_host_srv_count', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('Onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['protocol_type', 'service',
#                                                    'flag'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=-1, random_state=42))])

# %%
pred = rc.predict(x_test)

# %%
rc.score(x_test,y_test)
# Out:
# 0.7647711142654364

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[9445,  266],
#        [5037, 7796]])

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.97      0.78      9711
#            1       0.97      0.61      0.75     12833
#
#     accuracy                           0.76     22544
#    macro avg       0.81      0.79      0.76     22544
# weighted avg       0.83      0.76      0.76     22544

# %%
rc = make_pipeline(full_pipeline,RandomForestClassifier(random_state=42,n_jobs=-1))
param_grid = {
    "randomforestclassifier__n_estimators":[100,200],
    "randomforestclassifier__max_depth":[10,20,None],
    "randomforestclassifier__min_samples_split":[2,5],
    "randomforestclassifier__min_samples_leaf":[1,2],
    "randomforestclassifier__max_features": ["sqrt", "log2"]
}
grid_search = GridSearchCV(
    rc,
    param_grid,
    cv=5,
    scoring="recall",
    error_score="raise"
)
grid_search.fit(x_train,y_train)
model = grid_search.best_estimator_
model.score(x_test,y_test)
# Out:
# 0.7676543647977289

# %%
grid_search.best_params_
# Out:
# {'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__max_features': 'sqrt',
#  'randomforestclassifier__min_samples_leaf': 1,
#  'randomforestclassifier__min_samples_split': 2,
#  'randomforestclassifier__n_estimators': 200}

# %%
dt = make_pipeline(full_pipeline,DecisionTreeClassifier(random_state=42))
param_grid = {
    "decisiontreeclassifier__max_depth":[10,20,None],
    "decisiontreeclassifier__min_samples_split":[2,5],
    "decisiontreeclassifier__min_samples_leaf":[1,2],
    "decisiontreeclassifier__criterion":["gini","entropy"]
}
grid_search = GridSearchCV(
    dt,
    param_grid,
    cv=5,
    n_jobs=-1,
    scoring="recall",
    error_score="raise"
)
grid_search.fit(x_train,y_train)
model = grid_search.best_estimator_
model.score(x_test,y_test)
# Out:
# 0.7772799858055358

# %%
grid_search.best_params_
# Out:
# {'decisiontreeclassifier__criterion': 'entropy',
#  'decisiontreeclassifier__max_depth': 20,
#  'decisiontreeclassifier__min_samples_leaf': 1,
#  'decisiontreeclassifier__min_samples_split': 2}

# %%
rf = model.named_steps["decisiontreeclassifier"]
importance = rf.feature_importances_
feature_names = model.named_steps["columntransformer"].get_feature_names_out()
feature_importance = pd.DataFrame({
    "Feature":feature_names,
    "importance":importance
}).sort_values("importance",ascending=False)

# %%
feature_importance.head(20)
# Out:
#                              Feature  importance
# 1                     num__src_bytes    0.639525
# 56                cat__service_ecr_i    0.087455
# 26                num__diff_srv_rate    0.079495
# 65                 cat__service_http    0.042168
# 6                           num__hot    0.040436
# 2                     num__dst_bytes    0.029947
# 32  num__dst_host_same_src_port_rate    0.023876
# 61             cat__service_ftp_data    0.012872
# 29           num__dst_host_srv_count    0.007125
# 0                      num__duration    0.006162
# 35     num__dst_host_srv_serror_rate    0.004392
# 90              cat__service_private    0.003763
# 31       num__dst_host_diff_srv_rate    0.003554
# 34         num__dst_host_serror_rate    0.002406
# 19                        num__count    0.002325
# 30       num__dst_host_same_srv_rate    0.002226
# 36         num__dst_host_rerror_rate    0.001526
# 28               num__dst_host_count    0.001423
# 12                     num__num_root    0.001047
# 8                     num__logged_in    0.001010

# %%
imp = []
for i in range(0,30):
    imp.append(feature_importance["Feature"][i])
feature_importance.head(20).plot(kind="barh",x="Feature",y="importance")
plt.ylabel("Feature")
plt.xlabel("Importance")
plt.gca().invert_yaxis()
plt.title("Top 10 Feature ")
plt.show()

# %%
feature_names
top_num_attribute = []
top_cat_attribute = []
names =[]
for i in imp:
    ch = i.split("__")[1]
    if i.startswith("num__"):
        top_num_attribute.append(ch)
        names.append(ch)
    else:
        if ch[0]=='p' and "protocol_type" not in names:
            top_cat_attribute.append("protocol_type")
            names.append("protocol_type")
        elif ch[0]=='s' and "service" not in names:
            names.append("service")
            top_cat_attribute.append("service")
        elif ch[0]=='f' and "flag" not in names:
            top_cat_attribute.append("flag")
            names.append("flag")

# %%
x_top_train = x_train[names]
y_top_train = y_train
x_top_test = x_test[names]
y_top_test = y_test

# %%
num_pipeline = Pipeline([
    ('Scaler',StandardScaler())
])
cat_pipeline = Pipeline([
    ('Onehot',OneHotEncoder(handle_unknown='ignore'))
])
full_pipeline = ColumnTransformer([
    ("num",num_pipeline,top_num_attribute),
    ("cat",cat_pipeline,top_cat_attribute)
])

# %%
rc = make_pipeline(full_pipeline,RandomForestClassifier(random_state=42,n_jobs=-1))
rc.fit(x_top_train,y_top_train)
pred = rc.predict(x_top_test)
print(rc.score(x_top_test,y_top_test))
print(confusion_matrix(y_top_test,pred))
print(classification_report(y_top_test,pred))
# Out:
# 0.7597586941092974
# [[9437  274]
#  [5142 7691]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.97      0.78      9711
#            1       0.97      0.60      0.74     12833
#
#     accuracy                           0.76     22544
#    macro avg       0.81      0.79      0.76     22544
# weighted avg       0.83      0.76      0.76     22544

# %%
rc = make_pipeline(full_pipeline,RandomForestClassifier(random_state=42,n_jobs=-1))
param_grid = {
    "randomforestclassifier__n_estimators":[100,200],
    "randomforestclassifier__max_depth":[10,20,None],
    "randomforestclassifier__min_samples_split":[2,5],
    "randomforestclassifier__min_samples_leaf":[1,2],
    "randomforestclassifier__max_features": ["sqrt", "log2"]
}
grid_search = GridSearchCV(
    rc,
    param_grid,
    cv=5,
    scoring="recall",
    error_score="raise"
)
grid_search.fit(x_top_train,y_top_train)
model = grid_search.best_estimator_
model.score(x_top_test,y_top_test)
# Out:
# 0.7700053229240597

# %%
dt = make_pipeline(full_pipeline,DecisionTreeClassifier(random_state=42))
param_grid = {
    "decisiontreeclassifier__max_depth":[10,20,None],
    "decisiontreeclassifier__min_samples_split":[2,5],
    "decisiontreeclassifier__min_samples_leaf":[1,2],
    "decisiontreeclassifier__criterion":["gini","entropy"]
}
grid_search = GridSearchCV(
    dt,
    param_grid,
    cv=5,
    n_jobs=-1,
    scoring="recall",
    error_score="raise"
)
grid_search.fit(x_top_train,y_top_train)
model = grid_search.best_estimator_
model.score(x_top_test,y_top_test)
# Out:
# 0.810681334279631

# %%
pred = model.predict(x_top_test)
print(confusion_matrix(y_top_test,pred))
# Out:
# [[9421  290]
#  [3978 8855]]

# %%
print(classification_report(y_top_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.97      0.82      9711
#            1       0.97      0.69      0.81     12833
#
#     accuracy                           0.81     22544
#    macro avg       0.84      0.83      0.81     22544
# weighted avg       0.85      0.81      0.81     22544

# %%
fpr, tpr, threshold = roc_curve(y_top_test, y_prob)
roc_auc = roc_auc_score(y_top_test, y_prob)

print("ROC-AUC Score:", roc_auc)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.4f})")
plt.plot([0,1],[0,1])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ROC-AUC Score: 0.8338693092847246

# %%
y_prob = model.predict_proba(x_top_test)[:,1]

# %%
precision, recall, _ = precision_recall_curve(y_top_test, y_prob)
ap = average_precision_score(y_top_test, y_prob)
plt.figure(figsize=(8,6))
plt.plot(recall, precision, label=f"AP = {ap:.4f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.grid(True)
plt.legend()
plt.show()
